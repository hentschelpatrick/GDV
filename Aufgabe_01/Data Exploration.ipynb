# %%
import pandas as pd

# %%
data = pd.read_csv("./DAten/Beobachtungsdaten.csv", delimiter=",")
data
# Out:
#                 Alter Geschlecht Trunkenheitszustand
# 0                Kind          W            Nüchtern
# 1                Kind          W            Nüchtern
# 2                Kind          W            Nüchtern
# 3                Kind          W            Nüchtern
# 4                Kind          W            Nüchtern
# 5                Kind          W            Nüchtern
# 6                Kind          W            Nüchtern
# 7                Kind          W            Nüchtern
# 8                Kind          W            Nüchtern
# 9                Kind          W            Nüchtern
# 10               Kind          M            Nüchtern
# 11               Kind          M            Nüchtern
# 12               Kind          M            Nüchtern
# 13               Kind          M            Nüchtern
# 14               Kind          M            Nüchtern
# 15               Kind          M            Nüchtern
# 16               Kind          M            Nüchtern
# ...

# %% [markdown]
# # Kinder sind u18, junge Erwachsene 18-30, Erwachsene 30-80

# %%
data.groupby(["Alter", "Geschlecht"])["Geschlecht"].count()
# Out:
# Alter             Geschlecht
# Erwachsene        M             11
#                   W             32
# Junge Erwachsene  M             36
#                   W             23
# Kind              M              7
#                   W             10
# Name: Geschlecht, dtype: int64

# %%
data.groupby(["Geschlecht","Trunkenheitszustand"])["Trunkenheitszustand"].count()
# Out:
# Geschlecht  Trunkenheitszustand
# M           Angetrunken            32
#             Betrunken               7
#             Nüchtern               15
# W           Angetrunken            23
#             Betrunken              14
#             Nüchtern               28
# Name: Trunkenheitszustand, dtype: int64

# %%
data.to_csv("./DAten/Beobachtungsdaten.csv",index=False)

# %%
! pip3 install sklearn
# Out:
# ...
#   Running setup.py bdist_wheel for sklearn ... done
#   Stored in directory: /Users/patrickhentschel/Library/Caches/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# ...

# %%
from sklearn.uti import
